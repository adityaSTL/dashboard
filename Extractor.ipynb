# %%
import pandas as pd
import numpy as np




class extract_table:
    def extract_dprb(path):
        dprb=[]
        try:
            dprb=read_excel(path, sheet_name='Daywise Progress Report')
        except:
            print("DPR Pkg. B not found")
        return dprb       
            
    def extract_dprc(path):
        dprc=[]
        try:
            dprc=read_excel(path, sheet_name='Day Wise Progress')
        except:
            print("DPR Pkg. C not found") 
        return dprc     
    
    def extract_popb(path):
        popb=[]
        try:
            dprc=read_excel(path, sheet_name='GP PoP')
        except:
            print("POP Pkg. B not found") 
        return popb
    
    def extract_popc(path):
        popc=[]
        try:
            dprc=read_excel(path, sheet_name='GP PoP')
        except:
            print("POP Pkg. C not found") 
        return popc
    
    def extract_atcb(path):
        atcb=[]
        try:
            atcb=read_excel(path, sheet_name='Backup Sheet')
        except:
            print("ATC Pkg. B not found") 
        return atcb
    
    def extract_atcc(path6):
        atcc=[]
        try:
            atcc=read_excel(path, sheet_name='Master Sheet')
        except:
            print("ATC Pkg. C not found") 
        return atcc
